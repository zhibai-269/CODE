# %%
import scipy.io as sio
import numpy as np

# %%
def save_as_gml(nodes,edges):
    f = open('graph.gml','w')
    f.write('graph [\n')
    f.write('  node [\n')
    for i in nodes:
        f.write('    id '+str(i)+'\n')
        f.write('    label '+str(i)+'\n')

        f.write('  ]\n')

    for i in edges:
        f.write('  edge [\n')
        f.write('    source '+str(i[0])+'\n')
        f.write('    target '+str(i[1])+'\n')
        f.write('    label '+str(0)+'\n')
        f.write('  ]\n')
    f.write(']\n')

# %%
map_key=sio.loadmat("map_key.mat")

edges=[]
vertices=[]
for edge in map_key["map_key"][0]:
    edges.append(edge[0].split("+"))
print(edges)
for i in range(64984):
    vertices.append(i)

save_as_gml(nodes=vertices,edges=edges)
# Out:
# [['100', '0'], ['100', '25572'], ['1000', '0'], ['1001', '0'], ['1001', '33238'], ['1001', '33282'], ['1001', '789'], ['1001', '790'], ['10019', '0'], ['10019', '16943'], ['1002', '0'], ['1002', '33238'], ['1002', '33282'], ['1002', '789'], ['1002', '790'], ['10021', '0'], ['10021', '31488'], ['10025', '0'], ['10025', '16943'], ['10026', '0'], ['10026', '12548'], ['10039', '0'], ['10039', '17390'], ['1005', '0'], ['10054', '0'], ['10054', '12526'], ['1007', '0'], ['1007', '311'], ['1007', '312'], ['1007', '32857'], ['10076', '0'], ['10077', '0'], ['10077', '33193'], ['10077', '33238'], ['10077', '701'], ['10077', '745'], ['10077', '746'], ['1008', '0'], ['1008', '311'], ['1008', '312'], ['1008', '32857'], ['10085', '0'], ['1009', '0'], ['1009', '1156'], ['1009', '1189'], ['1009', '1190'], ['101', '0'], ['101', '25781'], ['1010', '0'], ['1010', '1156'], ['1010', '1189'], ['1010', '1190'], ['10108', '0'], ['10108', '8377'], ['10120', '0'], ['10120', '21638'], ['10121', '0'], ['10121', '11332'], ['10121', '18618'], ['10121', '3314'], ['10121', '35843'], ['10122', '0'], ['10122', '3227'], ['10122', '35766'], ['10122', '35779'], ['10126', '0'], ['10126', '9420'], ['10127', '0'], ['10127', '18562'], ['10131', '0'], ['10131', '18463'], ['10132', '0'], ['10132', '6305'], ['10144', '0'], ['10144', '10381'], ['10145', '0'], ['10145', '18610'], ['10145', '8421'], ['10145', '8422'], ['10146', '0'], ['10146', '16844'], ['10146', '17187'], ['10146', '17188'], ['10148', '0'], ['10148', '9709'], ['1015', '0'], ['1015', '3210'], ['1015', '35766'], ['10156', '0'], ['1016', '0'], ['10167', '0'], ['10167', '11309'], ['10168', '0'], ['10169', '0'], ['